# %%
import requests
from bs4 import BeautifulSoup as bs
import re

# %%
def convert_size(size):
    # Change every size into sq.ft
    if size.endswith('Sq. Yd.'):
        return round(float(size[:-7].strip().replace(',','')) * 9)
    elif size.endswith('Sq. M.'):
        return round(float(size[:-6].strip().replace(',','')) * 10.764)
    elif size.endswith('Marla'):
        return round(float(size[:-5].strip().replace(',','')) * 272.3)
    elif size.endswith('Kanal'):
        return round(float(size[:-5].strip().replace(',','')) * 5445)
    else:
        return round(float(size))

# %%
# st = '500,000 Sq. Yd.'
# st = str(st).strip()
# s = st.endswith('Sq. Yd.')
# s

# %%
# st[:-7].strip().replace(',','')

# %%
def convert_price(price):
    if price.endswith('Thousand'):
        return round(float(price[:-8].strip()) * 1000)
    elif price.endswith('Lakh'):
        return round(float(price[:-4].strip()) * 100000)
    elif price.endswith('Million'):
        return round(float(price[:-7].strip()) * 1000000)
    elif price.endswith('Crore'):
        return round(float(price[:-5].strip()) * 10000000)
    elif price.endswith('Arab'):
        return round(float(price[:-4].strip()) * 1000000000)
    else:
        return round(float(price))

# %%
def text(tag, datatype = 'str'):
    # num --> bed, bath,  str -->  location,  price --> price, size --> size
    if tag is None and datatype == 'num':
        return 0
        
    if tag is None and datatype == 'str':
        return ""
        
    if tag is None and datatype == 'price':
        return 0.0

    # New line
    if tag is None and datatype == 'size':
        return 0.0
        
    if datatype == 'num':
        try:
            return int(tag.text.strip())
        except ValueError:
            return 0

    if datatype == 'str':
        return tag.text.strip()
        
    if datatype == 'price':
        return convert_price(tag.text.strip())
        
    if datatype == 'size':
        return convert_size(tag.text.strip())

# %%
def scrape_pages(city, pages_range):
    house_info = []
    for page_num in range(1, pages_range+1):
        url = f'https://www.zameen.com/Houses_Property/{city}-{page_num}.html'
        print(url)
        response = requests.get(url)
        soup = bs(response.text, 'html.parser')
        house_list = soup.select("main > div > div > div > div > ul > li")

        prev_len = len(house_info)
        
        for house in house_list:
            location = house.select_one("div[aria-label='Location']")
            area = house.select_one("div[title] > div > div > span:nth-child(1)")
            beds = house.select_one("span[aria-label='Beds']")
            bath = house.select_one("span[aria-label='Baths']")
            price = house.select_one("span[aria-label='Price']")
            
            if price:
                house_info.append(
                    {
                        "location": text(location),
                        "area": text(area, datatype = "size"),
                        "price": text(price, datatype = "price"),
                        "num_of_bedrooms": text(beds, datatype = "num"),
                        "num_of_bathrooms": text(bath, datatype = "num")
                    }
                )
        if len(house_info) == prev_len:
            break
            
    return house_info

# %%
if __name__ == "__main__":
    house_info = []
    cities = [
        {'id':1, 'name':'Lahore'},
        {'id':2, 'name':'Karachi'},
        {'id':3, 'name':'Islamabad'},
        {'id':15, 'name':'Multan'},
        {'id':16, 'name':'Faisalabad'},
        {'id':17, 'name':'Peshawar'},
        {'id':18, 'name':'Quetta'},
        {'id':30, 'name':'Hyderabad'},
        {'id':36, 'name':'Murree'},
        {'id':41, 'name':'Rawalpindi'},
        {'id':327, 'name':'Gujranwala'},
        {'id': 1233, 'name': 'Attock'},
    ]
    
    for city in cities:
        house_info.append(
            {
                "city": city.get('name'),
                "info": scrape_pages(f"{city.get('name')}-{city.get('id')}", 50)
            }
        )
    with open("zameen.csv","w") as f:
        f.write("city|location|area_sq_ft|num_of_bedrooms|num_of_bathrooms|price_in_rupees\n")
        for house in house_info:
            for info in house.get('info'):
                #print(f"Writing row: city={house.get('city')}, location={info.get('location')}, area={info.get('area')}, price={info.get('price')}, beds={info.get('num_of_bedrooms')}, baths={info.get('num_of_bathrooms')}")
                f.write(
                    f"{house.get('city')}|{info.get('location')}|{info.get('area')}|{info.get('num_of_bedrooms')}|{info.get('num_of_bathrooms')}|{info.get('price')}\n"
                )
# Out:
# https://www.zameen.com/Houses_Property/Lahore-1-1.html
# https://www.zameen.com/Houses_Property/Lahore-1-2.html
# https://www.zameen.com/Houses_Property/Lahore-1-3.html
# https://www.zameen.com/Houses_Property/Lahore-1-4.html
# https://www.zameen.com/Houses_Property/Lahore-1-5.html
# https://www.zameen.com/Houses_Property/Lahore-1-6.html
# https://www.zameen.com/Houses_Property/Lahore-1-7.html
# https://www.zameen.com/Houses_Property/Lahore-1-8.html
# https://www.zameen.com/Houses_Property/Lahore-1-9.html
# https://www.zameen.com/Houses_Property/Lahore-1-10.html
# https://www.zameen.com/Houses_Property/Lahore-1-11.html
# https://www.zameen.com/Houses_Property/Lahore-1-12.html
# https://www.zameen.com/Houses_Property/Lahore-1-13.html
# https://www.zameen.com/Houses_Property/Lahore-1-14.html
# https://www.zameen.com/Houses_Property/Lahore-1-15.html
# https://www.zameen.com/Houses_Property/Lahore-1-16.html
# https://www.zameen.com/Houses_Property/Lahore-1-17.html
# https://www.zameen.com/Houses_Property/Lahore-1-18.html
# https://www.zameen.com/Houses_Property/Lahore-1-19.html
# https://www.zameen.com/Houses_Property/Lahore-1-20.html
# https://www.zameen.com/Houses_Property/Lahore-1-21.html
# https://www.zameen.com/Houses_Property/Lahore-1-22.html
# https://www.zameen.com/Houses_Property/Lahore-1-23.html
# https://www.zameen.com/Houses_Property/Lahore-1-24.html
# https://www.zameen.com/Houses_Property/Lahore-1-25.html
# https://www.zameen.com/Houses_Property/Lahore-1-26.html
# https://www.zameen.com/Houses_Property/Lahore-1-27.html
# https://www.zameen.com/Houses_Property/Lahore-1-28.html
# https://www.zameen.com/Houses_Property/Lahore-1-29.html
# https://www.zameen.com/Houses_Property/Lahore-1-30.html
# https://www.zameen.com/Houses_Property/Lahore-1-31.html
# https://www.zameen.com/Houses_Property/Lahore-1-32.html
# https://www.zameen.com/Houses_Property/Lahore-1-33.html
# https://www.zameen.com/Houses_Property/Lahore-1-34.html
# https://www.zameen.com/Houses_Property/Lahore-1-35.html
# https://www.zameen.com/Houses_Property/Lahore-1-36.html
# https://www.zameen.com/Houses_Property/Lahore-1-37.html
# https://www.zameen.com/Houses_Property/Lahore-1-38.html
# https://www.zameen.com/Houses_Property/Lahore-1-39.html
# https://www.zameen.com/Houses_Property/Lahore-1-40.html
# https://www.zameen.com/Houses_Property/Lahore-1-41.html
# https://www.zameen.com/Houses_Property/Lahore-1-42.html
# https://www.zameen.com/Houses_Property/Lahore-1-43.html
# https://www.zameen.com/Houses_Property/Lahore-1-44.html
# https://www.zameen.com/Houses_Property/Lahore-1-45.html
# https://www.zameen.com/Houses_Property/Lahore-1-46.html
# https://www.zameen.com/Houses_Property/Lahore-1-47.html
# https://www.zameen.com/Houses_Property/Lahore-1-48.html
# https://www.zameen.com/Houses_Property/Lahore-1-49.html
# https://www.zameen.com/Houses_Property/Lahore-1-50.html
# https://www.zameen.com/Houses_Property/Karachi-2-1.html
# https://www.zameen.com/Houses_Property/Karachi-2-2.html
# https://www.zameen.com/Houses_Property/Karachi-2-3.html
# https://www.zameen.com/Houses_Property/Karachi-2-4.html
# https://www.zameen.com/Houses_Property/Karachi-2-5.html
# https://www.zameen.com/Houses_Property/Karachi-2-6.html
# https://www.zameen.com/Houses_Property/Karachi-2-7.html
# https://www.zameen.com/Houses_Property/Karachi-2-8.html
# https://www.zameen.com/Houses_Property/Karachi-2-9.html
# https://www.zameen.com/Houses_Property/Karachi-2-10.html
# https://www.zameen.com/Houses_Property/Karachi-2-11.html
# https://www.zameen.com/Houses_Property/Karachi-2-12.html
# https://www.zameen.com/Houses_Property/Karachi-2-13.html
# https://www.zameen.com/Houses_Property/Karachi-2-14.html
# https://www.zameen.com/Houses_Property/Karachi-2-15.html
# https://www.zameen.com/Houses_Property/Karachi-2-16.html
# https://www.zameen.com/Houses_Property/Karachi-2-17.html
# https://www.zameen.com/Houses_Property/Karachi-2-18.html
# https://www.zameen.com/Houses_Property/Karachi-2-19.html
# https://www.zameen.com/Houses_Property/Karachi-2-20.html
# https://www.zameen.com/Houses_Property/Karachi-2-21.html
# https://www.zameen.com/Houses_Property/Karachi-2-22.html
# https://www.zameen.com/Houses_Property/Karachi-2-23.html
# https://www.zameen.com/Houses_Property/Karachi-2-24.html
# https://www.zameen.com/Houses_Property/Karachi-2-25.html
# https://www.zameen.com/Houses_Property/Karachi-2-26.html
# https://www.zameen.com/Houses_Property/Karachi-2-27.html
# https://www.zameen.com/Houses_Property/Karachi-2-28.html
# https://www.zameen.com/Houses_Property/Karachi-2-29.html
# https://www.zameen.com/Houses_Property/Karachi-2-30.html
# https://www.zameen.com/Houses_Property/Karachi-2-31.html
# https://www.zameen.com/Houses_Property/Karachi-2-32.html
# https://www.zameen.com/Houses_Property/Karachi-2-33.html
# https://www.zameen.com/Houses_Property/Karachi-2-34.html
# https://www.zameen.com/Houses_Property/Karachi-2-35.html
# https://www.zameen.com/Houses_Property/Karachi-2-36.html
# https://www.zameen.com/Houses_Property/Karachi-2-37.html
# https://www.zameen.com/Houses_Property/Karachi-2-38.html
# https://www.zameen.com/Houses_Property/Karachi-2-39.html
# https://www.zameen.com/Houses_Property/Karachi-2-40.html
# https://www.zameen.com/Houses_Property/Karachi-2-41.html
# https://www.zameen.com/Houses_Property/Karachi-2-42.html
# https://www.zameen.com/Houses_Property/Karachi-2-43.html
# https://www.zameen.com/Houses_Property/Karachi-2-44.html
# https://www.zameen.com/Houses_Property/Karachi-2-45.html
# https://www.zameen.com/Houses_Property/Karachi-2-46.html
# https://www.zameen.com/Houses_Property/Karachi-2-47.html
# https://www.zameen.com/Houses_Property/Karachi-2-48.html
# https://www.zameen.com/Houses_Property/Karachi-2-49.html
# https://www.zameen.com/Houses_Property/Karachi-2-50.html
# https://www.zameen.com/Houses_Property/Islamabad-3-1.html
# https://www.zameen.com/Houses_Property/Islamabad-3-2.html
# https://www.zameen.com/Houses_Property/Islamabad-3-3.html
# https://www.zameen.com/Houses_Property/Islamabad-3-4.html
# https://www.zameen.com/Houses_Property/Islamabad-3-5.html
# https://www.zameen.com/Houses_Property/Islamabad-3-6.html
# https://www.zameen.com/Houses_Property/Islamabad-3-7.html
# https://www.zameen.com/Houses_Property/Islamabad-3-8.html
# https://www.zameen.com/Houses_Property/Islamabad-3-9.html
# https://www.zameen.com/Houses_Property/Islamabad-3-10.html
# https://www.zameen.com/Houses_Property/Islamabad-3-11.html
# https://www.zameen.com/Houses_Property/Islamabad-3-12.html
# https://www.zameen.com/Houses_Property/Islamabad-3-13.html
# https://www.zameen.com/Houses_Property/Islamabad-3-14.html
# https://www.zameen.com/Houses_Property/Islamabad-3-15.html
# https://www.zameen.com/Houses_Property/Islamabad-3-16.html
# https://www.zameen.com/Houses_Property/Islamabad-3-17.html
# https://www.zameen.com/Houses_Property/Islamabad-3-18.html
# https://www.zameen.com/Houses_Property/Islamabad-3-19.html
# https://www.zameen.com/Houses_Property/Islamabad-3-20.html
# https://www.zameen.com/Houses_Property/Islamabad-3-21.html
# https://www.zameen.com/Houses_Property/Islamabad-3-22.html
# https://www.zameen.com/Houses_Property/Islamabad-3-23.html
# https://www.zameen.com/Houses_Property/Islamabad-3-24.html
# https://www.zameen.com/Houses_Property/Islamabad-3-25.html
# https://www.zameen.com/Houses_Property/Islamabad-3-26.html
# https://www.zameen.com/Houses_Property/Islamabad-3-27.html
# https://www.zameen.com/Houses_Property/Islamabad-3-28.html
# https://www.zameen.com/Houses_Property/Islamabad-3-29.html
# https://www.zameen.com/Houses_Property/Islamabad-3-30.html
# https://www.zameen.com/Houses_Property/Islamabad-3-31.html
# https://www.zameen.com/Houses_Property/Islamabad-3-32.html
# https://www.zameen.com/Houses_Property/Islamabad-3-33.html
# https://www.zameen.com/Houses_Property/Islamabad-3-34.html
# https://www.zameen.com/Houses_Property/Islamabad-3-35.html
# https://www.zameen.com/Houses_Property/Islamabad-3-36.html
# https://www.zameen.com/Houses_Property/Islamabad-3-37.html
# https://www.zameen.com/Houses_Property/Islamabad-3-38.html
# https://www.zameen.com/Houses_Property/Islamabad-3-39.html
# https://www.zameen.com/Houses_Property/Islamabad-3-40.html
# https://www.zameen.com/Houses_Property/Islamabad-3-41.html
# https://www.zameen.com/Houses_Property/Islamabad-3-42.html
# https://www.zameen.com/Houses_Property/Islamabad-3-43.html
# https://www.zameen.com/Houses_Property/Islamabad-3-44.html
# https://www.zameen.com/Houses_Property/Islamabad-3-45.html
# https://www.zameen.com/Houses_Property/Islamabad-3-46.html
# https://www.zameen.com/Houses_Property/Islamabad-3-47.html
# https://www.zameen.com/Houses_Property/Islamabad-3-48.html
# https://www.zameen.com/Houses_Property/Islamabad-3-49.html
# https://www.zameen.com/Houses_Property/Islamabad-3-50.html
# https://www.zameen.com/Houses_Property/Multan-15-1.html
# https://www.zameen.com/Houses_Property/Multan-15-2.html
# https://www.zameen.com/Houses_Property/Multan-15-3.html
# https://www.zameen.com/Houses_Property/Multan-15-4.html
# https://www.zameen.com/Houses_Property/Multan-15-5.html
# https://www.zameen.com/Houses_Property/Multan-15-6.html
# https://www.zameen.com/Houses_Property/Multan-15-7.html
# https://www.zameen.com/Houses_Property/Multan-15-8.html
# https://www.zameen.com/Houses_Property/Multan-15-9.html
# https://www.zameen.com/Houses_Property/Multan-15-10.html
# https://www.zameen.com/Houses_Property/Multan-15-11.html
# https://www.zameen.com/Houses_Property/Multan-15-12.html
# https://www.zameen.com/Houses_Property/Multan-15-13.html
# https://www.zameen.com/Houses_Property/Multan-15-14.html
# https://www.zameen.com/Houses_Property/Multan-15-15.html
# https://www.zameen.com/Houses_Property/Multan-15-16.html
# https://www.zameen.com/Houses_Property/Multan-15-17.html
# https://www.zameen.com/Houses_Property/Multan-15-18.html
# https://www.zameen.com/Houses_Property/Multan-15-19.html
# https://www.zameen.com/Houses_Property/Multan-15-20.html
# https://www.zameen.com/Houses_Property/Multan-15-21.html
# https://www.zameen.com/Houses_Property/Multan-15-22.html
# https://www.zameen.com/Houses_Property/Multan-15-23.html
# https://www.zameen.com/Houses_Property/Multan-15-24.html
# https://www.zameen.com/Houses_Property/Multan-15-25.html
# https://www.zameen.com/Houses_Property/Multan-15-26.html
# https://www.zameen.com/Houses_Property/Multan-15-27.html
# https://www.zameen.com/Houses_Property/Multan-15-28.html
# https://www.zameen.com/Houses_Property/Multan-15-29.html
# https://www.zameen.com/Houses_Property/Multan-15-30.html
# https://www.zameen.com/Houses_Property/Multan-15-31.html
# https://www.zameen.com/Houses_Property/Multan-15-32.html
# https://www.zameen.com/Houses_Property/Multan-15-33.html
# https://www.zameen.com/Houses_Property/Multan-15-34.html
# https://www.zameen.com/Houses_Property/Multan-15-35.html
# https://www.zameen.com/Houses_Property/Multan-15-36.html
# https://www.zameen.com/Houses_Property/Multan-15-37.html
# https://www.zameen.com/Houses_Property/Multan-15-38.html
# https://www.zameen.com/Houses_Property/Multan-15-39.html
# https://www.zameen.com/Houses_Property/Multan-15-40.html
# https://www.zameen.com/Houses_Property/Multan-15-41.html
# https://www.zameen.com/Houses_Property/Multan-15-42.html
# https://www.zameen.com/Houses_Property/Multan-15-43.html
# https://www.zameen.com/Houses_Property/Multan-15-44.html
# https://www.zameen.com/Houses_Property/Multan-15-45.html
# https://www.zameen.com/Houses_Property/Multan-15-46.html
# https://www.zameen.com/Houses_Property/Multan-15-47.html
# https://www.zameen.com/Houses_Property/Multan-15-48.html
# https://www.zameen.com/Houses_Property/Multan-15-49.html
# https://www.zameen.com/Houses_Property/Multan-15-50.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-1.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-2.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-3.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-4.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-5.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-6.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-7.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-8.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-9.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-10.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-11.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-12.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-13.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-14.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-15.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-16.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-17.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-18.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-19.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-20.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-21.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-22.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-23.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-24.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-25.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-26.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-27.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-28.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-29.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-30.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-31.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-32.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-33.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-34.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-35.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-36.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-37.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-38.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-39.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-40.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-41.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-42.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-43.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-44.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-45.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-46.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-47.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-48.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-49.html
# https://www.zameen.com/Houses_Property/Faisalabad-16-50.html
# https://www.zameen.com/Houses_Property/Peshawar-17-1.html
# https://www.zameen.com/Houses_Property/Peshawar-17-2.html
# https://www.zameen.com/Houses_Property/Peshawar-17-3.html
# https://www.zameen.com/Houses_Property/Peshawar-17-4.html
# https://www.zameen.com/Houses_Property/Peshawar-17-5.html
# https://www.zameen.com/Houses_Property/Peshawar-17-6.html
# https://www.zameen.com/Houses_Property/Peshawar-17-7.html
# https://www.zameen.com/Houses_Property/Peshawar-17-8.html
# https://www.zameen.com/Houses_Property/Peshawar-17-9.html
# https://www.zameen.com/Houses_Property/Peshawar-17-10.html
# https://www.zameen.com/Houses_Property/Peshawar-17-11.html
# https://www.zameen.com/Houses_Property/Peshawar-17-12.html
# https://www.zameen.com/Houses_Property/Peshawar-17-13.html
# https://www.zameen.com/Houses_Property/Peshawar-17-14.html
# https://www.zameen.com/Houses_Property/Peshawar-17-15.html
# https://www.zameen.com/Houses_Property/Peshawar-17-16.html
# https://www.zameen.com/Houses_Property/Peshawar-17-17.html
# https://www.zameen.com/Houses_Property/Peshawar-17-18.html
# https://www.zameen.com/Houses_Property/Peshawar-17-19.html
# https://www.zameen.com/Houses_Property/Peshawar-17-20.html
# https://www.zameen.com/Houses_Property/Peshawar-17-21.html
# https://www.zameen.com/Houses_Property/Peshawar-17-22.html
# https://www.zameen.com/Houses_Property/Peshawar-17-23.html
# https://www.zameen.com/Houses_Property/Peshawar-17-24.html
# https://www.zameen.com/Houses_Property/Peshawar-17-25.html
# https://www.zameen.com/Houses_Property/Peshawar-17-26.html
# https://www.zameen.com/Houses_Property/Peshawar-17-27.html
# https://www.zameen.com/Houses_Property/Peshawar-17-28.html
# https://www.zameen.com/Houses_Property/Peshawar-17-29.html
# https://www.zameen.com/Houses_Property/Peshawar-17-30.html
# https://www.zameen.com/Houses_Property/Peshawar-17-31.html
# https://www.zameen.com/Houses_Property/Peshawar-17-32.html
# https://www.zameen.com/Houses_Property/Peshawar-17-33.html
# https://www.zameen.com/Houses_Property/Peshawar-17-34.html
# https://www.zameen.com/Houses_Property/Peshawar-17-35.html
# https://www.zameen.com/Houses_Property/Peshawar-17-36.html
# https://www.zameen.com/Houses_Property/Peshawar-17-37.html
# https://www.zameen.com/Houses_Property/Peshawar-17-38.html
# https://www.zameen.com/Houses_Property/Peshawar-17-39.html
# https://www.zameen.com/Houses_Property/Peshawar-17-40.html
# https://www.zameen.com/Houses_Property/Peshawar-17-41.html
# https://www.zameen.com/Houses_Property/Quetta-18-1.html
# https://www.zameen.com/Houses_Property/Quetta-18-2.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-1.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-2.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-3.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-4.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-5.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-6.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-7.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-8.html
# https://www.zameen.com/Houses_Property/Hyderabad-30-9.html
# https://www.zameen.com/Houses_Property/Murree-36-1.html
# https://www.zameen.com/Houses_Property/Murree-36-2.html
# https://www.zameen.com/Houses_Property/Murree-36-3.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-1.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-2.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-3.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-4.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-5.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-6.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-7.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-8.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-9.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-10.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-11.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-12.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-13.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-14.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-15.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-16.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-17.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-18.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-19.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-20.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-21.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-22.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-23.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-24.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-25.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-26.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-27.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-28.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-29.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-30.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-31.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-32.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-33.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-34.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-35.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-36.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-37.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-38.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-39.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-40.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-41.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-42.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-43.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-44.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-45.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-46.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-47.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-48.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-49.html
# https://www.zameen.com/Houses_Property/Rawalpindi-41-50.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-1.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-2.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-3.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-4.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-5.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-6.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-7.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-8.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-9.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-10.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-11.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-12.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-13.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-14.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-15.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-16.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-17.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-18.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-19.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-20.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-21.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-22.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-23.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-24.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-25.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-26.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-27.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-28.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-29.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-30.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-31.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-32.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-33.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-34.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-35.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-36.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-37.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-38.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-39.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-40.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-41.html
# https://www.zameen.com/Houses_Property/Gujranwala-327-42.html
# https://www.zameen.com/Houses_Property/Attock-1233-1.html
# https://www.zameen.com/Houses_Property/Attock-1233-2.html

# %%
# cities = [
#         {'id':1, 'name':'Lahore'},
#         {'id':2, 'name':'Karachi'}]

# for city in cities:
#     print(f"{city.get('name'), city.get('id')}")
